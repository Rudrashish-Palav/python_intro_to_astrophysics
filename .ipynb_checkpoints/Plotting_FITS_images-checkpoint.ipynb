# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.io.fits as fits

# %%
data_i = fits.getdata(r"C:\Users\rudra\OneDrive\Desktop\Python_workshop\Frames\frame-i-003918-3-0213.fits.bz2")
data_u = fits.getdata(r"C:\Users\rudra\OneDrive\Desktop\Python_workshop\Frames\frame-u-003918-3-0213.fits.bz2")
data_r = fits.getdata(r"C:\Users\rudra\OneDrive\Desktop\Python_workshop\Frames\frame-r-003918-3-0213.fits.bz2")
data_z = fits.getdata(r"C:\Users\rudra\OneDrive\Desktop\Python_workshop\Frames\frame-z-003918-3-0213.fits.bz2")
data_g = fits.getdata(r"C:\Users\rudra\OneDrive\Desktop\Python_workshop\Frames\frame-g-003918-3-0213.fits.bz2")
print(f"Min and Max of frame i {np.percentile(data_i,[1,99])}")
print(f"Min and Max of frame u {np.percentile(data_u,[1,99])}")
print(f"Min and Max of frame r {np.percentile(data_r,[1,99])}")
print(f"Min and Max of frame z {np.percentile(data_z,[1,99])}")
print(f"Min and Max of frame g is {np.percentile(data_g,[1,99])}")
# Out:
# Min and Max of frame i [-0.08630371  0.11743164]
# Min and Max of frame u [-0.08728027  0.09716797]
# Min and Max of frame r [-0.0559082   0.07189941]
# Min and Max of frame z [-0.34716797  0.39941406]
# Min and Max of frame g is [-0.03509521  0.04193115]

# %%
fig,axs = plt.subplots(5,1, figsize = (15, 15))

axs[0].imshow(data_i, vmin =-0.08, vmax =0.11)
axs[0].set_title("Frame i")

axs[1].imshow(data_u, vmin = -0.08, vmax = 0.09)
axs[1].set_title("Frame u")

axs[2].imshow(data_r, vmin = -0.05, vmax = 0.07 )
axs[2].set_title("Frame r")

axs[3].imshow(data_z, vmin = -0.34, vmax =0.39 )
axs[3].set_title("Frame z")

axs[4].imshow(data_g, vmin = -0.03, vmax = 0.04 )
axs[4].set_title("Frame g")

plt.tight_layout()
